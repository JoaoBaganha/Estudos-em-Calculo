# %%
from sympy import *

# %%
x = symbols('x')
y = symbols('y')
z = symbols('z')
a = symbols('a')

# %%
func1 = 3 / sqrt(x - 2)
func1
# Out:
# 3/sqrt(x - 2)

# %%
limit(func1, x, 2)
# Out:
# oo

# %%
func1.subs(x, 2)
# Out:
# zoo

# %%
plot (func1, 2, xlim = (-20, 50), ylim = (-20, 50) )

# %%
func2 = (y**2 - 1) / (y - 1)
func2
# Out:
# (y**2 - 1)/(y - 1)

# %%
limit(func2, y, 1)
# Out:
# 2

# %%
plot(func2, 1)

# %%
func3 = 1 + sqrt(z - 3)
func3
# Out:
# sqrt(z - 3) + 1

# %%
limit(func3, z, 3)
# Out:
# 1

# %%
plot(func3, 3, xlim = (0, 9))

# %%
func4 =
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-0e3500e18531> in <cell line: 1>()
# ----> 1 func4
#
# NameError: name 'func4' is not defined
