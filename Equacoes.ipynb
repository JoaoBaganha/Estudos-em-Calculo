# %%
pip install sympy
# Out:
# ...
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.2 MB 435.7 kB/s eta 0:00:15
#    ---------------------------------------- 0.1/6.2 MB 550.5 kB/s eta 0:00:12
#    ---------------------------------------- 0.1/6.2 MB 550.5 kB/s eta 0:00:12
#     --------------------------------------- 0.1/6.2 MB 547.6 kB/s eta 0:00:12
#    - -------------------------------------- 0.2/6.2 MB 704.6 kB/s eta 0:00:09
#    - -------------------------------------- 0.2/6.2 MB 811.5 kB/s eta 0:00:08
#    - -------------------------------------- 0.3/6.2 MB 842.9 kB/s eta 0:00:08
#    -- ------------------------------------- 0.3/6.2 MB 925.5 kB/s eta 0:00:07
#    -- ------------------------------------- 0.3/6.2 MB 776.5 kB/s eta 0:00:08
#    -- ------------------------------------- 0.4/6.2 MB 836.4 kB/s eta 0:00:07
# ...

# %%
from sympy import *

# %%
x = symbols('x')

# %%
equation = x**2 + 3*x 
equation
# Out:
# x**2 + 3*x

# %%
Eq(equation, 20)
# Out:
# Eq(x**2 + 3*x, 20)

# %%
plot(equation)
# Out:
#     130 |                                                      /
#         |                                                     .
#         |
#         |                                                    .
#         |                                                   /
#         |                                                  /
#         |                                                 /
#         |                                                /
#         |                                               /
#         |\                                             /
#      65 |-\-------------------------------------------/---------
#         |  \                                         /
#         |   \                                       /
#         |    \                                    ..
#         |     ..                                 /
#         |       \                               /
#         |        ..                           ..
# ...
